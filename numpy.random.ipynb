# %% [markdown]
# # The Numpy Random Package
#
# [Official Documentation](https://numpy.org/doc/stable/reference/random/index.html)
#
# ***

# %%
import numpy as np

import matplotlib.pyplot as plt

# %%
# change size of plot 
plt.rcParams['figure.figsize'] = [10, 5]
# change style
plt.style.use("classic")

# %% [markdown]
# <br>
#
# ## copying code from the numpy.random.normal manual
#
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html
#
# ***

# %%
mu, sigma = 0, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)

# %%
# show top ten numbers in the s list 
s[:10]
# Out:
# array([ 0.21035983, -0.23136536, -0.07042788, -0.1423536 , -0.10944194,
#         0.13282079, -0.10925479,  0.02785094,  0.13782173, -0.12553329])

# %%
abs(mu - np.mean(s))
# Out:
# 0.0017623601416493757

# %%
abs(sigma - np.std(s, ddof=1))
# Out:
# 0.0016715358061703267

# %%
count, bins, ignored = plt.hist(s, 30, density=True)
f = 1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins - mu)**2 / (2 * sigma**2) )
plt.plot(bins, f, linewidth=2, color='r')
plt.show()

# %% [markdown]
# # References
#
# [1] https://numpy.org/doc/stable/reference/random/index.html
#
# [2] https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html
